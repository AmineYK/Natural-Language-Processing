# %% [markdown]
# # Word Embedding for Sequence Processing

# %% [markdown]
# **The goal of this practical is to use pre-trained word embedding for adressing the sequence prediction tasks studied in week 2: PoS and chunking.**

# %%
import numpy as np
import gensim.downloader as api
from gensim.models import KeyedVectors

# %% [markdown]
# ## 0) Loading PoS (or chunking) datasets (small or large)

# %%
def load(filename):
    listeDoc = list()
    with open(filename, "r") as f:
        doc = list()
        for ligne in f:
            #print "l : ",len(ligne)," ",ligne
            if len(ligne) < 2: # fin de doc
                listeDoc.append(doc)
                doc = list()
                continue
            mots = ligne.replace("\n","").split(" ")
            doc.append((mots[0],mots[2])) # mettre mots[2] à la place de mots[1] pour le chuncking
    return listeDoc

# %%
bSmall = False

if(bSmall==True):
    filename = "datasets/conll2000/chtrain.txt" 
    filenameT = "datasets/conll2000/chtest.txt" 

else:
    # Larger corpus .
    filename = "datasets/conll2000/train.txt" 
    filenameT = "datasets/conll2000/test.txt" 

alldocs = load(filename)
alldocsT = load(filenameT)

print(len(alldocs)," docs read")
print(len(alldocsT)," docs (T) read")
# Out:
# 8936  docs read
# 2012  docs (T) read

# %% [markdown]
# # 1) Word embedding for classifying each word

# %% [markdown]
# ### Pre-trained word2vec

# %%
import gensim.downloader as api
bload = True
fname = "word2vec-google-news-300"
sdir = "" 

if(bload==True):
    wv_pre_trained = KeyedVectors.load(sdir+fname+".dat")
else:  
    wv_pre_trained = api.load(fname)
    wv_pre_trained.save(sdir+fname+".dat")

# %% [markdown]
# ### Some token on the dataset are missing, we will encode them with a random vector
# This is sub-optimal, but we need to do something

# %%
def randomvec():
    
    default = np.random.randn(300)
    default = default  / np.linalg.norm(default)
    return default

# %%
np.random.seed(seed=10) # seed the randomness

dictadd = dict()
cpt=0
for d in alldocs:
    cpt+=1
    print(" ****** Document ******",cpt)
    for (x,pos) in d:
        if (not (x in wv_pre_trained) and not (x in dictadd)):
            print(x," not in WE, adding it with random vector")
            dictadd[x] = randomvec()
            
for d in alldocsT:
    cpt+=1
    print(" ****** TEST Document ******",cpt)
    for (x,pos) in d:
        if (not (x in wv_pre_trained) and not (x in dictadd)):
            print(x," not in WE, adding it with random vector")
            dictadd[x] = randomvec()
            #wv_pre_trained.add_vector(x,randomvec())
# Out:
#  ****** Document ****** 1
# to  not in WE, adding it with random vector
# ,  not in WE, adding it with random vector
# a  not in WE, adding it with random vector
# and  not in WE, adding it with random vector
# 's  not in WE, adding it with random vector
# near-record  not in WE, adding it with random vector
# .  not in WE, adding it with random vector
#  ****** Document ****** 2
# of  not in WE, adding it with random vector
#  ****** Document ****** 3
#  ****** Document ****** 4
# 16  not in WE, adding it with random vector
# 15  not in WE, adding it with random vector
#  ****** Document ****** 5
# ``  not in WE, adding it with random vector
# ''  not in WE, adding it with random vector
#  ****** Document ****** 6
#  ****** Document ****** 7
# -LRB-  not in WE, adding it with random vector
# 3.2  not in WE, adding it with random vector
# -RRB-  not in WE, adding it with random vector
#  ****** Document ****** 8
# 2.2  not in WE, adding it with random vector
# 2.3  not in WE, adding it with random vector
# 1988  not in WE, adding it with random vector
#  ****** Document ****** 9
#  ****** Document ****** 10
#  ****** Document ****** 11
# 1.8  not in WE, adding it with random vector
#  ****** Document ****** 12
#  ****** Document ****** 13
# 1.3  not in WE, adding it with random vector
#  ****** Document ****** 14
#  ****** Document ****** 15
#  ****** Document ****** 16
#  ****** Document ****** 17
#  ****** Document ****** 18
#  ****** Document ****** 19
#  ****** Document ****** 20
# 0.1  not in WE, adding it with random vector
# 3.8  not in WE, adding it with random vector
#  ****** Document ****** 21
# 1.6  not in WE, adding it with random vector
# 5.4  not in WE, adding it with random vector
#  ****** Document ****** 22
#  ****** Document ****** 23
#  ****** Document ****** 24
#  ****** Document ****** 25
#  ****** Document ****** 26
#  ****** Document ****** 27
#  ****** Document ****** 28
# 1.5890  not in WE, adding it with random vector
# 2.9495  not in WE, adding it with random vector
# 1.5940  not in WE, adding it with random vector
# 2.9429  not in WE, adding it with random vector
#  ****** Document ****** 29
# 2.90  not in WE, adding it with random vector
#  ****** Document ****** 30
#  ****** Document ****** 31
#  ****** Document ****** 32
# 13  not in WE, adding it with random vector
# 190  not in WE, adding it with random vector
#  ****** Document ****** 33
#  ****** Document ****** 34
# 1.8578  not in WE, adding it with random vector
# 1.8470  not in WE, adding it with random vector
#  ****** Document ****** 35
# 142.43  not in WE, adding it with random vector
# 141.70  not in WE, adding it with random vector
#  ****** Document ****** 36
# 141.95  not in WE, adding it with random vector
# 141.35  not in WE, adding it with random vector
#  ****** Document ****** 37
# 367.30  not in WE, adding it with random vector
# 20  not in WE, adding it with random vector
#  ****** Document ****** 38
# 2.4  not in WE, adding it with random vector
#  ****** Document ****** 39
# 366.50  not in WE, adding it with random vector
#  ****** Document ****** 40
# 40  not in WE, adding it with random vector
#  ****** Document ****** 41
# 19  not in WE, adding it with random vector
# 31  not in WE, adding it with random vector
#  ****** Document ****** 42
#  ****** Document ****** 43
#  ****** Document ****** 44
# 40-a-share  not in WE, adding it with random vector
# 106.6  not in WE, adding it with random vector
#  ****** Document ****** 45
# 2,664,098  not in WE, adding it with random vector
#  ****** Document ****** 46
# 38  not in WE, adding it with random vector
# 1.875  not in WE, adding it with random vector
# over-the-counter  not in WE, adding it with random vector
#  ****** Document ****** 47
#  ****** Document ****** 48
# 8.7  not in WE, adding it with random vector
#  ****** Document ****** 49
# 233,000  not in WE, adding it with random vector
# 30,000  not in WE, adding it with random vector
# 35.50  not in WE, adding it with random vector
# 36.50  not in WE, adding it with random vector
#  ****** Document ****** 50
# York-based  not in WE, adding it with random vector
# L.P  not in WE, adding it with random vector
#  ****** Document ****** 51
#  ****** Document ****** 52
#  ****** Document ****** 53
#  ****** Document ****** 54
# air-freight  not in WE, adding it with random vector
#  ****** Document ****** 55
#  ****** Document ****** 56
#  ****** Document ****** 57
#  ****** Document ****** 58
# freight-transport  not in WE, adding it with random vector
#  ****** Document ****** 59
# 10  not in WE, adding it with random vector
# 250  not in WE, adding it with random vector
# 30  not in WE, adding it with random vector
#  ****** Document ****** 60
# 1980  not in WE, adding it with random vector
# broad-based  not in WE, adding it with random vector
#  ****** Document ****** 61
#  ****** Document ****** 62
#  ****** Document ****** 63
# 35  not in WE, adding it with random vector
# inter-city  not in WE, adding it with random vector
# 150  not in WE, adding it with random vector
# 6.4  not in WE, adding it with random vector
# 1981  not in WE, adding it with random vector
#  ****** Document ****** 64
#  ****** Document ****** 65
# '  not in WE, adding it with random vector
#  ****** Document ****** 66
# transportation-cost  not in WE, adding it with random vector
#  ****** Document ****** 67
#  ****** Document ****** 68
# freight-cost  not in WE, adding it with random vector
#  ****** Document ****** 69
# freight-rate  not in WE, adding it with random vector
#  ****** Document ****** 70
#  ****** Document ****** 71
#  ****** Document ****** 72
#  ****** Document ****** 73
# Less-than-truckload  not in WE, adding it with random vector
# 4.7  not in WE, adding it with random vector
#  ****** Document ****** 74
#  ****** Document ****** 75
# Railroad-rate  not in WE, adding it with random vector
# rail-traffic  not in WE, adding it with random vector
#  ****** Document ****** 76
# less-than-truckload  not in WE, adding it with random vector
#  ****** Document ****** 77
# 5.3  not in WE, adding it with random vector
#  ****** Document ****** 78
#  ****** Document ****** 79
#  ****** Document ****** 80
# Air-freight  not in WE, adding it with random vector
#  ****** Document ****** 81
# 25  not in WE, adding it with random vector
#  ****** Document ****** 82
# air-freight-forwarding  not in WE, adding it with random vector
#  ****** Document ****** 83
#  ****** Document ****** 84
#  ****** Document ****** 85
#  ****** Document ****** 86
#  ****** Document ****** 87
#  ****** Document ****** 88
#  ****** Document ****** 89
# Calif.-based  not in WE, adding it with random vector
# 26.9  not in WE, adding it with random vector
#  ****** Document ****** 90
#  ****** Document ****** 91
# hotel\/casino  not in WE, adding it with random vector
#  ****** Document ****** 92
#  ****** Document ****** 93
# ;  not in WE, adding it with random vector
#  ****** Document ****** 94
#  ****** Document ****** 95
#  ****** Document ****** 96
# :  not in WE, adding it with random vector
#  ****** Document ****** 97
#  ****** Document ****** 98
#  ****** Document ****** 99
#  ****** Document ****** 100
#  ****** Document ****** 101
#  ****** Document ****** 102
#  ****** Document ****** 103
#  ****** Document ****** 104
#  ****** Document ****** 105
#  ****** Document ****** 106
#  ****** Document ****** 107
# Underseas  not in WE, adding it with random vector
#  ****** Document ****** 108
#  ****** Document ****** 109
# --  not in WE, adding it with random vector
# 60  not in WE, adding it with random vector
#  ****** Document ****** 110
# people-oriented  not in WE, adding it with random vector
#  ****** Document ****** 111
#  ****** Document ****** 112
# ex-employees  not in WE, adding it with random vector
#  ****** Document ****** 113
#  ****** Document ****** 114
#  ****** Document ****** 115
# ?  not in WE, adding it with random vector
#  ****** Document ****** 116
#  ****** Document ****** 117
#  ****** Document ****** 118
#  ****** Document ****** 119
#  ****** Document ****** 120
# 50  not in WE, adding it with random vector
# 75  not in WE, adding it with random vector
#  ****** Document ****** 121
# 12  not in WE, adding it with random vector
# complaint-resolution  not in WE, adding it with random vector
#  ****** Document ****** 122
#  ****** Document ****** 123
#  ****** Document ****** 124
# due-process  not in WE, adding it with random vector
#  ****** Document ****** 125
#  ****** Document ****** 126
#  ****** Document ****** 127
#  ****** Document ****** 128
#  ****** Document ****** 129
#  ****** Document ****** 130
#  ****** Document ****** 131
# fact-finder  not in WE, adding it with random vector
#  ****** Document ****** 132
# single-adjudicator  not in WE, adding it with random vector
#  ****** Document ****** 133
#  ****** Document ****** 134
#  ****** Document ****** 135
#  ****** Document ****** 136
#  ****** Document ****** 137
# Smith-Kline  not in WE, adding it with random vector
# closed-circuit  not in WE, adding it with random vector
#  ****** Document ****** 138
#  ****** Document ****** 139
#  ****** Document ****** 140
#  ****** Document ****** 141
# 1989  not in WE, adding it with random vector
#  ****** Document ****** 142
#  ****** Document ****** 143
#  ****** Document ****** 144
# 225  not in WE, adding it with random vector
# 112.16  not in WE, adding it with random vector
# 35486.38  not in WE, adding it with random vector
#  ****** Document ****** 145
# 266.66  not in WE, adding it with random vector
#  ****** Document ****** 146
# 101.98  not in WE, adding it with random vector
# 35588.36  not in WE, adding it with random vector
#  ****** Document ****** 147
# 862  not in WE, adding it with random vector
#  ****** Document ****** 148
# 572  not in WE, adding it with random vector
# 368  not in WE, adding it with random vector
# 181  not in WE, adding it with random vector
#  ****** Document ****** 149
# small-lot  not in WE, adding it with random vector
#  ****** Document ****** 150
# 35611.38  not in WE, adding it with random vector
# profit-taking  not in WE, adding it with random vector
#  ****** Document ****** 151
# Dai-ichi  not in WE, adding it with random vector
#  ****** Document ****** 152
# 22.78  not in WE, adding it with random vector
# 14.06  not in WE, adding it with random vector
# 0.53  not in WE, adding it with random vector
# 2679.72  not in WE, adding it with random vector
#  ****** Document ****** 153
# 15.72  not in WE, adding it with random vector
# 11.88  not in WE, adding it with random vector
# 0.32  not in WE, adding it with random vector
# 3717.46  not in WE, adding it with random vector
#  ****** Document ****** 154
# 28  not in WE, adding it with random vector
#  ****** Document ****** 155
# 647.33-point  not in WE, adding it with random vector
#  ****** Document ****** 156
# 6.9  not in WE, adding it with random vector
#  ****** Document ****** 157
#  ****** Document ****** 158
# 1017.69  not in WE, adding it with random vector
#  ****** Document ****** 159
#  ****** Document ****** 160
#  ****** Document ****** 161
# high-priced  not in WE, adding it with random vector
#  ****** Document ****** 162
# 450  not in WE, adding it with random vector
# 3.16  not in WE, adding it with random vector
# 6,050  not in WE, adding it with random vector
# 42.60  not in WE, adding it with random vector
#  ****** Document ****** 163
# 80  not in WE, adding it with random vector
# 5,440  not in WE, adding it with random vector
#  ****** Document ****** 164
# 100  not in WE, adding it with random vector
# 7,580  not in WE, adding it with random vector
#  ****** Document ****** 165
#  ****** Document ****** 166
# 1,920  not in WE, adding it with random vector
# 2,070  not in WE, adding it with random vector
#  ****** Document ****** 167
#  ****** Document ****** 168
# 2,660  not in WE, adding it with random vector
#  ****** Document ****** 169
# 2,960  not in WE, adding it with random vector
#  ****** Document ****** 170
# 2,120  not in WE, adding it with random vector
# Ohbayashi  not in WE, adding it with random vector
# 1,730  not in WE, adding it with random vector
#  ****** Document ****** 171
# 2,010  not in WE, adding it with random vector
# 230  not in WE, adding it with random vector
# 4,400  not in WE, adding it with random vector
#  ****** Document ****** 172
#  ****** Document ****** 173
# Times-Stock  not in WE, adding it with random vector
# 100-share  not in WE, adding it with random vector
# 10.2  not in WE, adding it with random vector
# 2179.1  not in WE, adding it with random vector
# 2176.9  not in WE, adding it with random vector
# 2189  not in WE, adding it with random vector
#  ****** Document ****** 174
# 2233.9  not in WE, adding it with random vector
#  ****** Document ****** 175
#  ****** Document ****** 176
# FT-SE  not in WE, adding it with random vector
# 11-point  not in WE, adding it with random vector
# establshed  not in WE, adding it with random vector
#  ****** Document ****** 177
# 30-share  not in WE, adding it with random vector
# 11.0  not in WE, adding it with random vector
# 1761.0  not in WE, adding it with random vector
#  ****** Document ****** 178
# 351.3  not in WE, adding it with random vector
# 387.4  not in WE, adding it with random vector
#  ****** Document ****** 179
#  ****** Document ****** 180
# market-makers  not in WE, adding it with random vector
#  ****** Document ****** 181
#  ****** Document ****** 182
# management-led  not in WE, adding it with random vector
#  ****** Document ****** 183
#  ****** Document ****** 184
# 390-million  not in WE, adding it with random vector
# 622  not in WE, adding it with random vector
#  ****** Document ****** 185
# 197  not in WE, adding it with random vector
#  ****** Document ****** 186
# 8.2  not in WE, adding it with random vector
#  ****** Document ****** 187
# top-tier  not in WE, adding it with random vector
# B.A.T  not in WE, adding it with random vector
# 13.4  not in WE, adding it with random vector
#  ****** Document ****** 188
#  ****** Document ****** 189
#  ****** Document ****** 190
# 778  not in WE, adding it with random vector
# 7.5  not in WE, adding it with random vector
#  ****** Document ****** 191
# mid-week  not in WE, adding it with random vector
#  ****** Document ****** 192
# Trusthouse  not in WE, adding it with random vector
# 294  not in WE, adding it with random vector
# Zoete  not in WE, adding it with random vector
# 271  not in WE, adding it with random vector
#  ****** Document ****** 193
#  ****** Document ****** 194
#  ****** Document ****** 195
#  ****** Document ****** 196
#  ****** Document ****** 197
#  ****** Document ****** 198
# 1969  not in WE, adding it with random vector
#  ****** Document ****** 199
# year-end  not in WE, adding it with random vector
#  ****** Document ****** 200
#  ****** Document ****** 201
#  ****** Document ****** 202
#  ****** Document ****** 203
#  ****** Document ****** 204
#  ****** Document ****** 205
#  ****** Document ****** 206
#  ****** Document ****** 207
#  ****** Document ****** 208
#  ****** Document ****** 209
#  ****** Document ****** 210
#  ****** Document ****** 211
#  ****** Document ****** 212
#  ****** Document ****** 213
#  ****** Document ****** 214
#  ****** Document ****** 215
#  ****** Document ****** 216
#  ****** Document ****** 217
#  ****** Document ****** 218
#  ****** Document ****** 219
# coup-planning  not in WE, adding it with random vector
#  ****** Document ****** 220
#  ****** Document ****** 221
#  ****** Document ****** 222
#  ****** Document ****** 223
#  ****** Document ****** 224
#  ****** Document ****** 225
#  ****** Document ****** 226
#  ****** Document ****** 227
#  ****** Document ****** 228
#  ****** Document ****** 229
#  ****** Document ****** 230
#  ****** Document ****** 231
#  ****** Document ****** 232
#  ****** Document ****** 233
# anti-American  not in WE, adding it with random vector
#  ****** Document ****** 234
#  ****** Document ****** 235
#  ****** Document ****** 236
#  ****** Document ****** 237
# 1970s  not in WE, adding it with random vector
#  ****** Document ****** 238
#  ****** Document ****** 239
#  ****** Document ****** 240
# short-term  not in WE, adding it with random vector
#  ****** Document ****** 241
# six-figure  not in WE, adding it with random vector
#  ****** Document ****** 242
# now-standard  not in WE, adding it with random vector
#  ****** Document ****** 243
#  ****** Document ****** 244
#  ****** Document ****** 245
# backed-up  not in WE, adding it with random vector
#  ****** Document ****** 246
# advertising-backed  not in WE, adding it with random vector
# 1974  not in WE, adding it with random vector
#  ****** Document ****** 247
# 120-day  not in WE, adding it with random vector
# high-grade  not in WE, adding it with random vector
#  ****** Document ****** 248
#  ****** Document ****** 249
#  ****** Document ****** 250
# Rounding-off  not in WE, adding it with random vector
#  ****** Document ****** 251
#  ****** Document ****** 252
# 54  not in WE, adding it with random vector
#  ****** Document ****** 253
# 470  not in WE, adding it with random vector
# 350  not in WE, adding it with random vector
#  ****** Document ****** 254
# tax-exempt  not in WE, adding it with random vector
# 71  not in WE, adding it with random vector
#  ****** Document ****** 255
# 1975  not in WE, adding it with random vector
#  ****** Document ****** 256
# Noxell  not in WE, adding it with random vector
# Hart-Scott-Rodino  not in WE, adding it with random vector
# 1.4  not in WE, adding it with random vector
# P&G  not in WE, adding it with random vector
#  ****** Document ****** 257
#  ****** Document ****** 258
# 0.272  not in WE, adding it with random vector
# 11  not in WE, adding it with random vector
#  ****** Document ****** 259
#  ****** Document ****** 260
# health-care  not in WE, adding it with random vector
#  ****** Document ****** 261
# Messerschmitt-Boelkow-Blohm  not in WE, adding it with random vector
# G.m.b  not in WE, adding it with random vector
# Daimler-Benz  not in WE, adding it with random vector
# 17  not in WE, adding it with random vector
#  ****** Document ****** 262
# 50.01  not in WE, adding it with random vector
#  ****** Document ****** 263
#  ****** Document ****** 264
#  ****** Document ****** 265
#  ****** Document ****** 266
#  ****** Document ****** 267
# 2.5  not in WE, adding it with random vector
#  ****** Document ****** 268
# addiction-treatment  not in WE, adding it with random vector
#  ****** Document ****** 269
#  ****** Document ****** 270
# third-quarter  not in WE, adding it with random vector
#  ****** Document ****** 271
# McGraw-Hill  not in WE, adding it with random vector
#  ****** Document ****** 272
# 3.5  not in WE, adding it with random vector
# 4.6  not in WE, adding it with random vector
#  ****** Document ****** 273
#  ****** Document ****** 274
# fixed-income  not in WE, adding it with random vector
#  ****** Document ****** 275
# mid-October  not in WE, adding it with random vector
#  ****** Document ****** 276
# previous-month  not in WE, adding it with random vector
#  ****** Document ****** 277
#  ****** Document ****** 278
#  ****** Document ****** 279
# one-day  not in WE, adding it with random vector
# 190-point  not in WE, adding it with random vector
#  ****** Document ****** 280
#  ****** Document ****** 281
#  ****** Document ****** 282
# fourth-quarter  not in WE, adding it with random vector
#  ****** Document ****** 283
# 3.3  not in WE, adding it with random vector
#  ****** Document ****** 284
#  ****** Document ****** 285
#  ****** Document ****** 286
#  ****** Document ****** 287
# Fleet\/Norstar  not in WE, adding it with random vector
# 3.7  not in WE, adding it with random vector
#  ****** Document ****** 288
# 2.1  not in WE, adding it with random vector
#  ****** Document ****** 289
# stock-market  not in WE, adding it with random vector
#  ****** Document ****** 290
# 0.5  not in WE, adding it with random vector
# 0.3  not in WE, adding it with random vector
#  ****** Document ****** 291
# 0.4  not in WE, adding it with random vector
# 0.9  not in WE, adding it with random vector
#  ****** Document ****** 292
# 0.2  not in WE, adding it with random vector
# personal-income  not in WE, adding it with random vector
#  ****** Document ****** 293
# 3.9  not in WE, adding it with random vector
#  ****** Document ****** 294
#  ****** Document ****** 295
#  ****** Document ****** 296
# 11th  not in WE, adding it with random vector
#  ****** Document ****** 297
#  ****** Document ****** 298
# 15.02  not in WE, adding it with random vector
# 14.6  not in WE, adding it with random vector
# 13.7  not in WE, adding it with random vector
#  ****** Document ****** 299
# I.E.P.  not in WE, adding it with random vector
# Kong-based  not in WE, adding it with random vector
# 38.8  not in WE, adding it with random vector
#  ****** Document ****** 300
#  ****** Document ****** 301
#  ****** Document ****** 302
#  ****** Document ****** 303
#  ****** Document ****** 304
#  ****** Document ****** 305
# 1980s  not in WE, adding it with random vector
#  ****** Document ****** 306
#  ****** Document ****** 307
# 45-year-old  not in WE, adding it with random vector
#  ****** Document ****** 308
# little-known  not in WE, adding it with random vector
#  ****** Document ****** 309
#  ****** Document ****** 310
#  ****** Document ****** 311
#  ****** Document ****** 312
#  ****** Document ****** 313
#  ****** Document ****** 314
#  ****** Document ****** 315
# 386  not in WE, adding it with random vector
#  ****** Document ****** 316
# SKr1.5  not in WE, adding it with random vector
#  ****** Document ****** 317
#  ****** Document ****** 318
# Bfree  not in WE, adding it with random vector
# SKr29  not in WE, adding it with random vector
# 4.48  not in WE, adding it with random vector
# SKr205  not in WE, adding it with random vector
# 31.65  not in WE, adding it with random vector
#  ****** Document ****** 319
# SKr20  not in WE, adding it with random vector
# SKr225  not in WE, adding it with random vector
#  ****** Document ****** 320
#  ****** Document ****** 321
#  ****** Document ****** 322
#  ****** Document ****** 323
# 59  not in WE, adding it with random vector
#  ****** Document ****** 324
#  ****** Document ****** 325
#  ****** Document ****** 326
#  ****** Document ****** 327
#  ****** Document ****** 328
#  ****** Document ****** 329
# fastest-growing  not in WE, adding it with random vector
#  ****** Document ****** 330
# 1985  not in WE, adding it with random vector
#  ****** Document ****** 331
# 1.7  not in WE, adding it with random vector
# Herslow  not in WE, adding it with random vector
#  ****** Document ****** 332
#  ****** Document ****** 333
#  ****** Document ****** 334
# world-class  not in WE, adding it with random vector
#  ****** Document ****** 335
# Anglo-American  not in WE, adding it with random vector
# Kurtanjek  not in WE, adding it with random vector
#  ****** Document ****** 336
#  ****** Document ****** 337
#  ****** Document ****** 338
#  ****** Document ****** 339
# 68  not in WE, adding it with random vector
#  ****** Document ****** 340
#  ****** Document ****** 341
#  ****** Document ****** 342
#  ****** Document ****** 343
#  ****** Document ****** 344
#  ****** Document ****** 345
# break-up  not in WE, adding it with random vector
#  ****** Document ****** 346
#  ****** Document ****** 347
# 50-50  not in WE, adding it with random vector
#  ****** Document ****** 348
#  ****** Document ****** 349
#  ****** Document ****** 350
# '90s  not in WE, adding it with random vector
#  ****** Document ****** 351
#  ****** Document ****** 352
#  ****** Document ****** 353
#  ****** Document ****** 354
# 48  not in WE, adding it with random vector
#  ****** Document ****** 355
# 29  not in WE, adding it with random vector
# 113  not in WE, adding it with random vector
# 87  not in WE, adding it with random vector
# year-earlier  not in WE, adding it with random vector
# 107.9  not in WE, adding it with random vector
# 84  not in WE, adding it with random vector
#  ****** Document ****** 356
# 161.1  not in WE, adding it with random vector
# 1.24  not in WE, adding it with random vector
#  ****** Document ****** 357
#  ****** Document ****** 358
# 18  not in WE, adding it with random vector
# 1.38  not in WE, adding it with random vector
# 1.17  not in WE, adding it with random vector
#  ****** Document ****** 359
# full-year  not in WE, adding it with random vector
# 1.5  not in WE, adding it with random vector
# 406  not in WE, adding it with random vector
# 400.3  not in WE, adding it with random vector
# 3.08  not in WE, adding it with random vector
#  ****** Document ****** 360
# 454  not in WE, adding it with random vector
# 3.53  not in WE, adding it with random vector
#  ****** Document ****** 361
# 5.28  not in WE, adding it with random vector
# 4.07  not in WE, adding it with random vector
#  ****** Document ****** 362
# SE\/30  not in WE, adding it with random vector
# IIcx  not in WE, adding it with random vector
#  ****** Document ****** 363
#  ****** Document ****** 364
# ...  not in WE, adding it with random vector
#  ****** Document ****** 365
# 51  not in WE, adding it with random vector
# 49.2  not in WE, adding it with random vector
#  ****** Document ****** 366
# 49  not in WE, adding it with random vector
#  ****** Document ****** 367
#  ****** Document ****** 368
# 1990  not in WE, adding it with random vector
#  ****** Document ****** 369
# 44  not in WE, adding it with random vector
#  ****** Document ****** 370
# Polymerix  not in WE, adding it with random vector
# lumber-like  not in WE, adding it with random vector
#  ****** Document ****** 371
#  ****** Document ****** 372
#  ****** Document ****** 373
#  ****** Document ****** 374
# Polycast  not in WE, adding it with random vector
#  ****** Document ****** 375
#  ****** Document ****** 376
# 750,000  not in WE, adding it with random vector
#  ****** Document ****** 377
#  ****** Document ****** 378
# Kushkin  not in WE, adding it with random vector
#  ****** Document ****** 379
#  ****** Document ****** 380
#  ****** Document ****** 381
# 400  not in WE, adding it with random vector
# R.I  not in WE, adding it with random vector
#  ****** Document ****** 382
# Ebasco  not in WE, adding it with random vector
# Enserch  not in WE, adding it with random vector
# 250-megawatt  not in WE, adding it with random vector
#  ****** Document ****** 383
#  ****** Document ****** 384
#  ****** Document ****** 385
#  ****** Document ****** 386
# 4.4  not in WE, adding it with random vector
#  ****** Document ****** 387
# 36  not in WE, adding it with random vector
# 1,200  not in WE, adding it with random vector
#  ****** Document ****** 388
# 500  not in WE, adding it with random vector
#  ****** Document ****** 389
# 300  not in WE, adding it with random vector
#  ****** Document ****** 390
#  ****** Document ****** 391
#  ****** Document ****** 392
#  ****** Document ****** 393
#  ****** Document ****** 394
# Asia\/Australia  not in WE, adding it with random vector
#  ****** Document ****** 395
#  ****** Document ****** 396
#  ****** Document ****** 397
#  ****** Document ****** 398
# 53  not in WE, adding it with random vector
# 500-store  not in WE, adding it with random vector
#  ****** Document ****** 399
#  ****** Document ****** 400
#  ****** Document ****** 401
# stock-quote  not in WE, adding it with random vector
# Infotechnology  not in WE, adding it with random vector
#  ****** Document ****** 402
#  ****** Document ****** 403
# 10,000  not in WE, adding it with random vector
#  ****** Document ****** 404
#  ****** Document ****** 405
# four-year-old  not in WE, adding it with random vector
#  ****** Document ****** 406
#  ****** Document ****** 407
#  ****** Document ****** 408
#  ****** Document ****** 409
#  ****** Document ****** 410
#  ****** Document ****** 411
#  ****** Document ****** 412
#  ****** Document ****** 413
# cotton-ginning  not in WE, adding it with random vector
#  ****** Document ****** 414
#  ****** Document ****** 415
# 1987  not in WE, adding it with random vector
# 20-year  not in WE, adding it with random vector
#  ****** Document ****** 416
#  ****** Document ****** 417
#  ****** Document ****** 418
#  ****** Document ****** 419
#  ****** Document ****** 420
# 1.03  not in WE, adding it with random vector
#  ****** Document ****** 421
#  ****** Document ****** 422
# multibillion-dollar  not in WE, adding it with random vector
# agrarian-reform  not in WE, adding it with random vector
#  ****** Document ****** 423
#  ****** Document ****** 424
#  ****** Document ****** 425
#  ****** Document ****** 426
#  ****** Document ****** 427
#  ****** Document ****** 428
#  ****** Document ****** 429
# government-held  not in WE, adding it with random vector
# 1986  not in WE, adding it with random vector
#  ****** Document ****** 430
#  ****** Document ****** 431
#  ****** Document ****** 432
#  ****** Document ****** 433
#  ****** Document ****** 434
# state-owned  not in WE, adding it with random vector
# 671  not in WE, adding it with random vector
#  ****** Document ****** 435
#  ****** Document ****** 436
#  ****** Document ****** 437
#  ****** Document ****** 438
#  ****** Document ****** 439
#  ****** Document ****** 440
# cash-strapped  not in WE, adding it with random vector
#  ****** Document ****** 441
# 1983  not in WE, adding it with random vector
# 98  not in WE, adding it with random vector
#  ****** Document ****** 442
#  ****** Document ****** 443
#  ****** Document ****** 444
#  ****** Document ****** 445
#  ****** Document ****** 446
# 45  not in WE, adding it with random vector
#  ****** Document ****** 447
#  ****** Document ****** 448
# non-controlling  not in WE, adding it with random vector
#  ****** Document ****** 449
# cash-hungry  not in WE, adding it with random vector
#  ****** Document ****** 450
#  ****** Document ****** 451
#  ****** Document ****** 452
#  ****** Document ****** 453
# short-changing  not in WE, adding it with random vector
#  ****** Document ****** 454
#  ****** Document ****** 455
# long-delayed  not in WE, adding it with random vector
# 99  not in WE, adding it with random vector
#  ****** Document ****** 456
# trans-Pacific  not in WE, adding it with random vector
# debt-laden  not in WE, adding it with random vector
#  ****** Document ****** 457
#  ****** Document ****** 458
#  ****** Document ****** 459
#  ****** Document ****** 460
# 65  not in WE, adding it with random vector
#  ****** Document ****** 461
#  ****** Document ****** 462
# bank-holding  not in WE, adding it with random vector
# tax-free  not in WE, adding it with random vector
#  ****** Document ****** 463
# Webster\/Eagle  not in WE, adding it with random vector
# 1.2  not in WE, adding it with random vector
#  ****** Document ****** 464
# 115  not in WE, adding it with random vector
#  ****** Document ****** 465
#  ****** Document ****** 466
#  ****** Document ****** 467
# 0.95  not in WE, adding it with random vector
#  ****** Document ****** 468
# 12.5  not in WE, adding it with random vector
#  ****** Document ****** 469
# 12.375  not in WE, adding it with random vector
#  ****** Document ****** 470
# 2.6  not in WE, adding it with random vector
#  ****** Document ****** 471
# 43.3  not in WE, adding it with random vector
# 28.6  not in WE, adding it with random vector
#  ****** Document ****** 472
#  ****** Document ****** 473
#  ****** Document ****** 474
#  ****** Document ****** 475
#  ****** Document ****** 476
#  ****** Document ****** 477
#  ****** Document ****** 478
# 699  not in WE, adding it with random vector
#  ****** Document ****** 479
# 469.6  not in WE, adding it with random vector
#  ****** Document ****** 480
#  ****** Document ****** 481
# Mexico-United  not in WE, adding it with random vector
# world-wide  not in WE, adding it with random vector
# free-market  not in WE, adding it with random vector
#  ****** Document ****** 482
#  ****** Document ****** 483
#  ****** Document ****** 484
#  ****** Document ****** 485
#  ****** Document ****** 486
#  ****** Document ****** 487
# 392  not in WE, adding it with random vector
# -LCB-  not in WE, adding it with random vector
# -RCB-  not in WE, adding it with random vector
# 1,155  not in WE, adding it with random vector
# 1982  not in WE, adding it with random vector
#  ****** Document ****** 488
#  ****** Document ****** 489
#  ****** Document ****** 490
#  ****** Document ****** 491
#  ****** Document ****** 492
#  ****** Document ****** 493
#  ****** Document ****** 494
#  ****** Document ****** 495
#  ****** Document ****** 496
# pluri-party  not in WE, adding it with random vector
#  ****** Document ****** 497
#  ****** Document ****** 498
#  ****** Document ****** 499
# third-largest  not in WE, adding it with random vector
#  ****** Document ****** 500
#  ****** Document ****** 501
# labor-management  not in WE, adding it with random vector
# buy-out  not in WE, adding it with random vector
#  ****** Document ****** 502
# 240  not in WE, adding it with random vector
# 5.09  not in WE, adding it with random vector
# 5.42  not in WE, adding it with random vector
#  ****** Document ****** 503
#  ****** Document ****** 504
#  ****** Document ****** 505
# 300-a-share  not in WE, adding it with random vector
# 6.79  not in WE, adding it with random vector
#  ****** Document ****** 506
# 168.50  not in WE, adding it with random vector
# 21.625  not in WE, adding it with random vector
#  ****** Document ****** 507
#  ****** Document ****** 508
#  ****** Document ****** 509
#  ****** Document ****** 510
# pilot-management  not in WE, adding it with random vector
#  ****** Document ****** 511
#  ****** Document ****** 512
# 200  not in WE, adding it with random vector
#  ****** Document ****** 513
# 22.6  not in WE, adding it with random vector
#  ****** Document ****** 514
#  ****** Document ****** 515
#  ****** Document ****** 516
# second-largest  not in WE, adding it with random vector
#  ****** Document ****** 517
#  ****** Document ****** 518
#  ****** Document ****** 519
# cooling-off  not in WE, adding it with random vector
#  ****** Document ****** 520
#  ****** Document ****** 521
# one-third  not in WE, adding it with random vector
#  ****** Document ****** 522
#  ****** Document ****** 523
#  ****** Document ****** 524
#  ****** Document ****** 525
#  ****** Document ****** 526
#  ****** Document ****** 527
#  ****** Document ****** 528
#  ****** Document ****** 529
#  ****** Document ****** 530
# third-party  not in WE, adding it with random vector
#  ****** Document ****** 531
#  ****** Document ****** 532
#  ****** Document ****** 533
#  ****** Document ****** 534
# 26.7  not in WE, adding it with random vector
#  ****** Document ****** 535
#  ****** Document ****** 536
#  ****** Document ****** 537
# two-minute  not in WE, adding it with random vector
# Spanish-language  not in WE, adding it with random vector
# 80%-owned  not in WE, adding it with random vector
#  ****** Document ****** 538
#  ****** Document ****** 539
# ad-supported  not in WE, adding it with random vector
#  ****** Document ****** 540
# 10-year  not in WE, adding it with random vector
# 1984  not in WE, adding it with random vector
#  ****** Document ****** 541
# 7\/8  not in WE, adding it with random vector
# 99.5  not in WE, adding it with random vector
# 10.958  not in WE, adding it with random vector
#  ****** Document ****** 542
# 60.3  not in WE, adding it with random vector
#  ****** Document ****** 543
#  ****** Document ****** 544
# 62.42  not in WE, adding it with random vector
#  ****** Document ****** 545
#  ****** Document ****** 546
#  ****** Document ****** 547
# 3,513,072  not in WE, adding it with random vector
#  ****** Document ****** 548
#  ****** Document ****** 549
# 6.05  not in WE, adding it with random vector
# 68.42  not in WE, adding it with random vector
#  ****** Document ****** 550
# 1.10  not in WE, adding it with random vector
# 62.36  not in WE, adding it with random vector
#  ****** Document ****** 551
#  ****** Document ****** 552
# 5.67  not in WE, adding it with random vector
# 39.08  not in WE, adding it with random vector
# 11.07  not in WE, adding it with random vector
#  ****** Document ****** 553
# 247  not in WE, adding it with random vector
# 9.49  not in WE, adding it with random vector
# 142  not in WE, adding it with random vector
# 8.79  not in WE, adding it with random vector
#  ****** Document ****** 554
#  ****** Document ****** 555
#  ****** Document ****** 556
#  ****** Document ****** 557
#  ****** Document ****** 558
#  ****** Document ****** 559
#  ****** Document ****** 560
# 42  not in WE, adding it with random vector
#  ****** Document ****** 561
# 69  not in WE, adding it with random vector
#  ****** Document ****** 562
#  ****** Document ****** 563
#  ****** Document ****** 564
# 26.48  not in WE, adding it with random vector
#  ****** Document ****** 565
# 263,684  not in WE, adding it with random vector
# 9.9375  not in WE, adding it with random vector
# 10.5625  not in WE, adding it with random vector
#  ****** Document ****** 566
# 6,727,042  not in WE, adding it with random vector
#  ****** Document ****** 567
#  ****** Document ****** 568
#  ****** Document ****** 569
#  ****** Document ****** 570
#  ****** Document ****** 571
#  ****** Document ****** 572
# 2.75  not in WE, adding it with random vector
# 43  not in WE, adding it with random vector
#  ****** Document ****** 573
#  ****** Document ****** 574
#  ****** Document ****** 575
#  ****** Document ****** 576
#  ****** Document ****** 577
# 700  not in WE, adding it with random vector
#  ****** Document ****** 578
#  ****** Document ****** 579
#  ****** Document ****** 580
#  ****** Document ****** 581
# 5.94  not in WE, adding it with random vector
# 2689.14  not in WE, adding it with random vector
# 119.88  not in WE, adding it with random vector
#  ****** Document ****** 582
#  ****** Document ****** 583
#  ****** Document ****** 584
# real-estate  not in WE, adding it with random vector
#  ****** Document ****** 585
# property-loan  not in WE, adding it with random vector
#  ****** Document ****** 586
#  ****** Document ****** 587
#  ****** Document ****** 588
#  ****** Document ****** 589
# London-based  not in WE, adding it with random vector
#  ****** Document ****** 590
# Qintex  not in WE, adding it with random vector
# Angeles-based  not in WE, adding it with random vector
#  ****** Document ****** 591
# MGM\/UA  not in WE, adding it with random vector
#  ****** Document ****** 592
# high-definition  not in WE, adding it with random vector
#  ****** Document ****** 593
# HDTV-screen  not in WE, adding it with random vector
#  ****** Document ****** 594
#  ****** Document ****** 595
#  ****** Document ****** 596
# oil-producing  not in WE, adding it with random vector
# 476.5  not in WE, adding it with random vector
#  ****** Document ****** 597
#  ****** Document ****** 598
#  ****** Document ****** 599
#  ****** Document ****** 600
#  ****** Document ****** 601
# 164,830,000  not in WE, adding it with random vector
#  ****** Document ****** 602
# 1230.80  not in WE, adding it with random vector
# 32.71  not in WE, adding it with random vector
# 215.48  not in WE, adding it with random vector
# 0.06  not in WE, adding it with random vector
#  ****** Document ****** 603
#  ****** Document ****** 604
# 3392.49  not in WE, adding it with random vector
#  ****** Document ****** 605
#  ****** Document ****** 606
# 129.62  not in WE, adding it with random vector
# 0.51  not in WE, adding it with random vector
# 131.34  not in WE, adding it with random vector
# 0.88  not in WE, adding it with random vector
#  ****** Document ****** 607
#  ****** Document ****** 608
# 0.73  not in WE, adding it with random vector
# 0.0108  not in WE, adding it with random vector
#  ****** Document ****** 609
# Inmac  not in WE, adding it with random vector
# money-losing  not in WE, adding it with random vector
#  ****** Document ****** 610
#  ****** Document ****** 611
# 4.75  not in WE, adding it with random vector
#  ****** Document ****** 612
# 12.3  not in WE, adding it with random vector
# write-off  not in WE, adding it with random vector
# 9.7  not in WE, adding it with random vector
# 1.02  not in WE, adding it with random vector
#  ****** Document ****** 613
# 249.5  not in WE, adding it with random vector
# 222.8  not in WE, adding it with random vector
#  ****** Document ****** 614
#  ****** Document ****** 615
# new-country  not in WE, adding it with random vector
#  ****** Document ****** 616
# 3,500  not in WE, adding it with random vector
#  ****** Document ****** 617
# Pharmics  not in WE, adding it with random vector
# N.Y  not in WE, adding it with random vector
#  ****** Document ****** 618
#  ****** Document ****** 619
# mioxidil  not in WE, adding it with random vector
# chlorazepate  not in WE, adding it with random vector
# dipotassium  not in WE, adding it with random vector
# meclofenamate  not in WE, adding it with random vector
#  ****** Document ****** 620
# trazadone  not in WE, adding it with random vector
# lorazapam  not in WE, adding it with random vector
#  ****** Document ****** 621
#  ****** Document ****** 622
#  ****** Document ****** 623
# 21  not in WE, adding it with random vector
#  ****** Document ****** 624
#  ****** Document ****** 625
# 105  not in WE, adding it with random vector
#  ****** Document ****** 626
# 73  not in WE, adding it with random vector
# 91  not in WE, adding it with random vector
# 160  not in WE, adding it with random vector
#  ****** Document ****** 627
# Year-earlier  not in WE, adding it with random vector
# per-share  not in WE, adding it with random vector
#  ****** Document ****** 628
# 7.7  not in WE, adding it with random vector
# 1.28  not in WE, adding it with random vector
# 1.18  not in WE, adding it with random vector
#  ****** Document ****** 629
#  ****** Document ****** 630
#  ****** Document ****** 631
#  ****** Document ****** 632
# 18.50  not in WE, adding it with random vector
#  ****** Document ****** 633
# Miami-based  not in WE, adding it with random vector
#  ****** Document ****** 634
# Hershhenson  not in WE, adding it with random vector
# Ciporkin  not in WE, adding it with random vector
#  ****** Document ****** 635
# 5.7  not in WE, adding it with random vector
#  ****** Document ****** 636
# Telectronics  not in WE, adding it with random vector
#  ****** Document ****** 637
#  ****** Document ****** 638
# 2,400  not in WE, adding it with random vector
#  ****** Document ****** 639
# 1,700  not in WE, adding it with random vector
#  ****** Document ****** 640
#  ****** Document ****** 641
# 1\/2-year  not in WE, adding it with random vector
#  ****** Document ****** 642
# second-quarter  not in WE, adding it with random vector
# 22  not in WE, adding it with random vector
# antianemia  not in WE, adding it with random vector
#  ****** Document ****** 643
# 97  not in WE, adding it with random vector
# 42.5  not in WE, adding it with random vector
#  ****** Document ****** 644
# year-ago  not in WE, adding it with random vector
# 320,000  not in WE, adding it with random vector
# 21.5  not in WE, adding it with random vector
#  ****** Document ****** 645
# 26  not in WE, adding it with random vector
# 625,000  not in WE, adding it with random vector
#  ****** Document ****** 646
# 77  not in WE, adding it with random vector
# 72.6  not in WE, adding it with random vector
# 41  not in WE, adding it with random vector
#  ****** Document ****** 647
#  ****** Document ****** 648
# power-sharing  not in WE, adding it with random vector
# 14-year-old  not in WE, adding it with random vector
#  ****** Document ****** 649
# League-sponsored  not in WE, adding it with random vector
#  ****** Document ****** 650
# pull-out  not in WE, adding it with random vector
# 33,000  not in WE, adding it with random vector
#  ****** Document ****** 651
# BRACED  not in WE, adding it with random vector
# earthquake-related  not in WE, adding it with random vector
#  ****** Document ****** 652
#  ****** Document ****** 653
# 57-year-old  not in WE, adding it with random vector
#  ****** Document ****** 654
#  ****** Document ****** 655
#  ****** Document ****** 656
#  ****** Document ****** 657
#  ****** Document ****** 658
#  ****** Document ****** 659
#  ****** Document ****** 660
#  ****** Document ****** 661
#  ****** Document ****** 662
#  ****** Document ****** 663
# 49-nation  not in WE, adding it with random vector
#  ****** Document ****** 664
#  ****** Document ****** 665
#  ****** Document ****** 666
#  ****** Document ****** 667
#  ****** Document ****** 668
#  ****** Document ****** 669
# 69-26  not in WE, adding it with random vector
#  ****** Document ****** 670
#  ****** Document ****** 671
# 76,000  not in WE, adding it with random vector
# Wedtech  not in WE, adding it with random vector
#  ****** Document ****** 672
# 20,000  not in WE, adding it with random vector
# interest-free  not in WE, adding it with random vector
#  ****** Document ****** 673
# 132  not in WE, adding it with random vector
# 146  not in WE, adding it with random vector
#  ****** Document ****** 674
# 727  not in WE, adding it with random vector
#  ****** Document ****** 675
#  ****** Document ****** 676
# Arab-Israeli  not in WE, adding it with random vector
#  ****** Document ****** 677
#  ****** Document ****** 678
#  ****** Document ****** 679
# U.S.-backed  not in WE, adding it with random vector
#  ****** Document ****** 680
# organ-transplant  not in WE, adding it with random vector
#  ****** Document ****** 681
# interleukin-4  not in WE, adding it with random vector
#  ****** Document ****** 682
# 79  not in WE, adding it with random vector
#  ****** Document ****** 683
# 72  not in WE, adding it with random vector
# 62  not in WE, adding it with random vector
# 39  not in WE, adding it with random vector
# telephone-access  not in WE, adding it with random vector
# long-distance  not in WE, adding it with random vector
#  ****** Document ****** 684
# one-time  not in WE, adding it with random vector
# financial-services  not in WE, adding it with random vector
#  ****** Document ****** 685
# 8.3  not in WE, adding it with random vector
# 780  not in WE, adding it with random vector
# 720  not in WE, adding it with random vector
#  ****** Document ****** 686
# Telephone-operations  not in WE, adding it with random vector
# federal-systems  not in WE, adding it with random vector
# 33  not in WE, adding it with random vector
#  ****** Document ****** 687
#  ****** Document ****** 688
# Customer-access  not in WE, adding it with random vector
#  ****** Document ****** 689
#  ****** Document ****** 690
# 33.75  not in WE, adding it with random vector
# .50  not in WE, adding it with random vector
#  ****** Document ****** 691
#  ****** Document ****** 692
#  ****** Document ****** 693
#  ****** Document ****** 694
#  ****** Document ****** 695
# knee-jerk  not in WE, adding it with random vector
# 52-year-old  not in WE, adding it with random vector
#  ****** Document ****** 696
#  ****** Document ****** 697
#  ****** Document ****** 698
#  ****** Document ****** 699
#  ****** Document ****** 700
# Soviet-style  not in WE, adding it with random vector
#  ****** Document ****** 701
# 43-year-old  not in WE, adding it with random vector
#  ****** Document ****** 702
#  ****** Document ****** 703
#  ****** Document ****** 704
#  ****** Document ****** 705
#  ****** Document ****** 706
#  ****** Document ****** 707
# Eppelmann  not in WE, adding it with random vector
#  ****** Document ****** 708
#  ****** Document ****** 709
#  ****** Document ****** 710
#  ****** Document ****** 711
#  ****** Document ****** 712
#  ****** Document ****** 713
#  ****** Document ****** 714
#  ****** Document ****** 715
#  ****** Document ****** 716
#  ****** Document ****** 717
#  ****** Document ****** 718
# two-hour  not in WE, adding it with random vector
#  ****** Document ****** 719
#  ****** Document ****** 720
#  ****** Document ****** 721
#  ****** Document ****** 722
#  ****** Document ****** 723
#  ****** Document ****** 724
#  ****** Document ****** 725
#  ****** Document ****** 726
#  ****** Document ****** 727
# anti-Soviet  not in WE, adding it with random vector
# 1953  not in WE, adding it with random vector
#  ****** Document ****** 728
#  ****** Document ****** 729
#  ****** Document ****** 730
#  ****** Document ****** 731
#  ****** Document ****** 732
# out-of-touch  not in WE, adding it with random vector
#  ****** Document ****** 733
#  ****** Document ****** 734
# 30-year-old  not in WE, adding it with random vector
#  ****** Document ****** 735
#  ****** Document ****** 736
#  ****** Document ****** 737
#  ****** Document ****** 738
#  ****** Document ****** 739
# state-controlled  not in WE, adding it with random vector
#  ****** Document ****** 740
#  ****** Document ****** 741
#  ****** Document ****** 742
#  ****** Document ****** 743
#  ****** Document ****** 744
#  ****** Document ****** 745
#  ****** Document ****** 746
#  ****** Document ****** 747
# 24  not in WE, adding it with random vector
#  ****** Document ****** 748
#  ****** Document ****** 749
# 1,300  not in WE, adding it with random vector
#  ****** Document ****** 750
# 1,500  not in WE, adding it with random vector
#  ****** Document ****** 751
#  ****** Document ****** 752
#  ****** Document ****** 753
#  ****** Document ****** 754
# electrolysis-of-water  not in WE, adding it with random vector
#  ****** Document ****** 755
#  ****** Document ****** 756
#  ****** Document ****** 757
#  ****** Document ****** 758
#  ****** Document ****** 759
#  ****** Document ****** 760
#  ****** Document ****** 761
#  ****** Document ****** 762
#  ****** Document ****** 763
#  ****** Document ****** 764
# A&M  not in WE, adding it with random vector
#  ****** Document ****** 765
#  ****** Document ****** 766
#  ****** Document ****** 767
#  ****** Document ****** 768
#  ****** Document ****** 769
#  ****** Document ****** 770
#  ****** Document ****** 771
#  ****** Document ****** 772
#  ****** Document ****** 773
#  ****** Document ****** 774
# ...
#  ****** TEST Document ****** 10661
#  ****** TEST Document ****** 10662
#  ****** TEST Document ****** 10663
# 140.95  not in WE, adding it with random vector
#  ****** TEST Document ****** 10664
# 1.8435  not in WE, adding it with random vector
#  ****** TEST Document ****** 10665
# 141  not in WE, adding it with random vector
#  ****** TEST Document ****** 10666
#  ****** TEST Document ****** 10667
#  ****** TEST Document ****** 10668
#  ****** TEST Document ****** 10669
#  ****** TEST Document ****** 10670
#  ****** TEST Document ****** 10671
#  ****** TEST Document ****** 10672
#  ****** TEST Document ****** 10673
#  ****** TEST Document ****** 10674
# currencny  not in WE, adding it with random vector
#  ****** TEST Document ****** 10675
# 141.85  not in WE, adding it with random vector
#  ****** TEST Document ****** 10676
# 1.5753  not in WE, adding it with random vector
#  ****** TEST Document ****** 10677
# 142.55  not in WE, adding it with random vector
#  ****** TEST Document ****** 10678
# 142.25  not in WE, adding it with random vector
#  ****** TEST Document ****** 10679
#  ****** TEST Document ****** 10680
#  ****** TEST Document ****** 10681
#  ****** TEST Document ****** 10682
#  ****** TEST Document ****** 10683
#  ****** TEST Document ****** 10684
#  ****** TEST Document ****** 10685
#  ****** TEST Document ****** 10686
#  ****** TEST Document ****** 10687
#  ****** TEST Document ****** 10688
#  ****** TEST Document ****** 10689
#  ****** TEST Document ****** 10690
# 367.40  not in WE, adding it with random vector
#  ****** TEST Document ****** 10691
#  ****** TEST Document ****** 10692
# 366.55  not in WE, adding it with random vector
#  ****** TEST Document ****** 10693
#  ****** TEST Document ****** 10694
#  ****** TEST Document ****** 10695
#  ****** TEST Document ****** 10696
#  ****** TEST Document ****** 10697
#  ****** TEST Document ****** 10698
#  ****** TEST Document ****** 10699
#  ****** TEST Document ****** 10700
# record-breaking  not in WE, adding it with random vector
# 68-week  not in WE, adding it with random vector
# ABC-TV  not in WE, adding it with random vector
#  ****** TEST Document ****** 10701
#  ****** TEST Document ****** 10702
# 13.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10703
# 904,000  not in WE, adding it with random vector
#  ****** TEST Document ****** 10704
# 18th  not in WE, adding it with random vector
#  ****** TEST Document ****** 10705
# highest-rated  not in WE, adding it with random vector
#  ****** TEST Document ****** 10706
#  ****** TEST Document ****** 10707
# 1962-63  not in WE, adding it with random vector
#  ****** TEST Document ****** 10708
#  ****** TEST Document ****** 10709
#  ****** TEST Document ****** 10710
# Butter-Nut  not in WE, adding it with random vector
#  ****** TEST Document ****** 10711
#  ****** TEST Document ****** 10712
#  ****** TEST Document ****** 10713
#  ****** TEST Document ****** 10714
#  ****** TEST Document ****** 10715
#  ****** TEST Document ****** 10716
# coffee-roasting  not in WE, adding it with random vector
#  ****** TEST Document ****** 10717
# BLOEDEL  not in WE, adding it with random vector
#  ****** TEST Document ****** 10718
#  ****** TEST Document ****** 10719
#  ****** TEST Document ****** 10720
#  ****** TEST Document ****** 10721
#  ****** TEST Document ****** 10722
#  ****** TEST Document ****** 10723
#  ****** TEST Document ****** 10724
#  ****** TEST Document ****** 10725
#  ****** TEST Document ****** 10726
#  ****** TEST Document ****** 10727
#  ****** TEST Document ****** 10728
#  ****** TEST Document ****** 10729
#  ****** TEST Document ****** 10730
#  ****** TEST Document ****** 10731
#  ****** TEST Document ****** 10732
#  ****** TEST Document ****** 10733
#  ****** TEST Document ****** 10734
#  ****** TEST Document ****** 10735
# 105.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10736
# investment-bank  not in WE, adding it with random vector
# securities-firm  not in WE, adding it with random vector
#  ****** TEST Document ****** 10737
#  ****** TEST Document ****** 10738
#  ****** TEST Document ****** 10739
#  ****** TEST Document ****** 10740
#  ****** TEST Document ****** 10741
#  ****** TEST Document ****** 10742
#  ****** TEST Document ****** 10743
# MicroGeneSys  not in WE, adding it with random vector
#  ****** TEST Document ****** 10744
# VaxSyn  not in WE, adding it with random vector
# HIV-1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10745
# innoculating  not in WE, adding it with random vector
#  ****** TEST Document ****** 10746
#  ****** TEST Document ****** 10747
#  ****** TEST Document ****** 10748
#  ****** TEST Document ****** 10749
#  ****** TEST Document ****** 10750
#  ****** TEST Document ****** 10751
#  ****** TEST Document ****** 10752
#  ****** TEST Document ****** 10753
# machine-tool  not in WE, adding it with random vector
#  ****** TEST Document ****** 10754
#  ****** TEST Document ****** 10755
# RobertsCorp  not in WE, adding it with random vector
#  ****** TEST Document ****** 10756
# 8.292  not in WE, adding it with random vector
# 91-day  not in WE, adding it with random vector
# 8.483  not in WE, adding it with random vector
#  ****** TEST Document ****** 10757
#  ****** TEST Document ****** 10758
# 7.986  not in WE, adding it with random vector
# 182-day  not in WE, adding it with random vector
# 8.1255  not in WE, adding it with random vector
#  ****** TEST Document ****** 10759
# 415  not in WE, adding it with random vector
#  ****** TEST Document ****** 10760
#  ****** TEST Document ****** 10761
#  ****** TEST Document ****** 10762
# 38.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10763
# 378  not in WE, adding it with random vector
#  ****** TEST Document ****** 10764
# 163  not in WE, adding it with random vector
#  ****** TEST Document ****** 10765
#  ****** TEST Document ****** 10766
# 199  not in WE, adding it with random vector
#  ****** TEST Document ****** 10767
# 10.16  not in WE, adding it with random vector
# 8.85  not in WE, adding it with random vector
#  ****** TEST Document ****** 10768
# N.D  not in WE, adding it with random vector
#  ****** TEST Document ****** 10769
#  ****** TEST Document ****** 10770
#  ****** TEST Document ****** 10771
#  ****** TEST Document ****** 10772
#  ****** TEST Document ****** 10773
#  ****** TEST Document ****** 10774
#  ****** TEST Document ****** 10775
#  ****** TEST Document ****** 10776
# 60.7  not in WE, adding it with random vector
# 2.32  not in WE, adding it with random vector
#  ****** TEST Document ****** 10777
# 601.3  not in WE, adding it with random vector
# 618.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10778
#  ****** TEST Document ****** 10779
#  ****** TEST Document ****** 10780
#  ****** TEST Document ****** 10781
# vinyl-products  not in WE, adding it with random vector
# 30.1  not in WE, adding it with random vector
# 64.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10782
# specialty-chemicals  not in WE, adding it with random vector
# 24.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10783
#  ****** TEST Document ****** 10784
# Ohio-based  not in WE, adding it with random vector
# 49.125  not in WE, adding it with random vector
#  ****** TEST Document ****** 10785
#  ****** TEST Document ****** 10786
#  ****** TEST Document ****** 10787
#  ****** TEST Document ****** 10788
#  ****** TEST Document ****** 10789
#  ****** TEST Document ****** 10790
#  ****** TEST Document ****** 10791
#  ****** TEST Document ****** 10792
#  ****** TEST Document ****** 10793
#  ****** TEST Document ****** 10794
#  ****** TEST Document ****** 10795
#  ****** TEST Document ****** 10796
#  ****** TEST Document ****** 10797
#  ****** TEST Document ****** 10798
#  ****** TEST Document ****** 10799
#  ****** TEST Document ****** 10800
#  ****** TEST Document ****** 10801
#  ****** TEST Document ****** 10802
#  ****** TEST Document ****** 10803
#  ****** TEST Document ****** 10804
#  ****** TEST Document ****** 10805
#  ****** TEST Document ****** 10806
#  ****** TEST Document ****** 10807
#  ****** TEST Document ****** 10808
# most-active  not in WE, adding it with random vector
#  ****** TEST Document ****** 10809
#  ****** TEST Document ****** 10810
#  ****** TEST Document ****** 10811
#  ****** TEST Document ****** 10812
#  ****** TEST Document ****** 10813
#  ****** TEST Document ****** 10814
# UBS-Phillips  not in WE, adding it with random vector
#  ****** TEST Document ****** 10815
#  ****** TEST Document ****** 10816
#  ****** TEST Document ****** 10817
#  ****** TEST Document ****** 10818
# 316  not in WE, adding it with random vector
#  ****** TEST Document ****** 10819
#  ****** TEST Document ****** 10820
#  ****** TEST Document ****** 10821
#  ****** TEST Document ****** 10822
#  ****** TEST Document ****** 10823
#  ****** TEST Document ****** 10824
#  ****** TEST Document ****** 10825
#  ****** TEST Document ****** 10826
#  ****** TEST Document ****** 10827
# 12.60  not in WE, adding it with random vector
#  ****** TEST Document ****** 10828
# Seattle-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10829
# 180,000  not in WE, adding it with random vector
#  ****** TEST Document ****** 10830
#  ****** TEST Document ****** 10831
#  ****** TEST Document ****** 10832
#  ****** TEST Document ****** 10833
# C-S  not in WE, adding it with random vector
# 107,100  not in WE, adding it with random vector
#  ****** TEST Document ****** 10834
#  ****** TEST Document ****** 10835
#  ****** TEST Document ****** 10836
# JAGRY  not in WE, adding it with random vector
#  ****** TEST Document ****** 10837
#  ****** TEST Document ****** 10838
#  ****** TEST Document ****** 10839
#  ****** TEST Document ****** 10840
# 44.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10841
#  ****** TEST Document ****** 10842
# 21.2  not in WE, adding it with random vector
#  ****** TEST Document ****** 10843
# Averae  not in WE, adding it with random vector
# 182.9  not in WE, adding it with random vector
#  ****** TEST Document ****** 10844
#  ****** TEST Document ****** 10845
#  ****** TEST Document ****** 10846
#  ****** TEST Document ****** 10847
#  ****** TEST Document ****** 10848
# 49.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10849
# 11-a-share  not in WE, adding it with random vector
# electronic-measuring  not in WE, adding it with random vector
#  ****** TEST Document ****** 10850
#  ****** TEST Document ****** 10851
#  ****** TEST Document ****** 10852
#  ****** TEST Document ****** 10853
# 9.482  not in WE, adding it with random vector
# 5.80  not in WE, adding it with random vector
#  ****** TEST Document ****** 10854
# 7.567  not in WE, adding it with random vector
#  ****** TEST Document ****** 10855
#  ****** TEST Document ****** 10856
#  ****** TEST Document ****** 10857
#  ****** TEST Document ****** 10858
# 76.6  not in WE, adding it with random vector
# 120.6  not in WE, adding it with random vector
#  ****** TEST Document ****** 10859
#  ****** TEST Document ****** 10860
# 51.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10861
# 626.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10862
#  ****** TEST Document ****** 10863
# 49.6  not in WE, adding it with random vector
#  ****** TEST Document ****** 10864
# 235.2  not in WE, adding it with random vector
# 176.4  not in WE, adding it with random vector
#  ****** TEST Document ****** 10865
# 6.50  not in WE, adding it with random vector
#  ****** TEST Document ****** 10866
#  ****** TEST Document ****** 10867
# 2.875  not in WE, adding it with random vector
# 78.625  not in WE, adding it with random vector
#  ****** TEST Document ****** 10868
# 73.50  not in WE, adding it with random vector
#  ****** TEST Document ****** 10869
#  ****** TEST Document ****** 10870
#  ****** TEST Document ****** 10871
#  ****** TEST Document ****** 10872
# 21.1  not in WE, adding it with random vector
# 20.7  not in WE, adding it with random vector
#  ****** TEST Document ****** 10873
#  ****** TEST Document ****** 10874
# high-performance  not in WE, adding it with random vector
#  ****** TEST Document ****** 10875
# quarter-to-quarter  not in WE, adding it with random vector
#  ****** TEST Document ****** 10876
#  ****** TEST Document ****** 10877
#  ****** TEST Document ****** 10878
# reduced-instruction  not in WE, adding it with random vector
#  ****** TEST Document ****** 10879
#  ****** TEST Document ****** 10880
#  ****** TEST Document ****** 10881
# RISC-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10882
#  ****** TEST Document ****** 10883
# supermainframe  not in WE, adding it with random vector
# generalpurpose  not in WE, adding it with random vector
#  ****** TEST Document ****** 10884
# UAL'S  not in WE, adding it with random vector
# SKIDDED  not in WE, adding it with random vector
#  ****** TEST Document ****** 10885
# 87.25  not in WE, adding it with random vector
#  ****** TEST Document ****** 10886
# back-up  not in WE, adding it with random vector
#  ****** TEST Document ****** 10887
#  ****** TEST Document ****** 10888
#  ****** TEST Document ****** 10889
#  ****** TEST Document ****** 10890
#  ****** TEST Document ****** 10891
#  ****** TEST Document ****** 10892
#  ****** TEST Document ****** 10893
#  ****** TEST Document ****** 10894
#  ****** TEST Document ****** 10895
#  ****** TEST Document ****** 10896
#  ****** TEST Document ****** 10897
#  ****** TEST Document ****** 10898
#  ****** TEST Document ****** 10899
#  ****** TEST Document ****** 10900
#  ****** TEST Document ****** 10901
#  ****** TEST Document ****** 10902
#  ****** TEST Document ****** 10903
#  ****** TEST Document ****** 10904
#  ****** TEST Document ****** 10905
#  ****** TEST Document ****** 10906
#  ****** TEST Document ****** 10907
#  ****** TEST Document ****** 10908
#  ****** TEST Document ****** 10909
#  ****** TEST Document ****** 10910
#  ****** TEST Document ****** 10911
#  ****** TEST Document ****** 10912
#  ****** TEST Document ****** 10913
#  ****** TEST Document ****** 10914
# 214.54  not in WE, adding it with random vector
# 0.19  not in WE, adding it with random vector
#  ****** TEST Document ****** 10915
# 3377.43  not in WE, adding it with random vector
#  ****** TEST Document ****** 10916
# 129.72  not in WE, adding it with random vector
# 129.97  not in WE, adding it with random vector
#  ****** TEST Document ****** 10917
# 0.0018  not in WE, adding it with random vector
#  ****** TEST Document ****** 10918
#  ****** TEST Document ****** 10919
#  ****** TEST Document ****** 10920
#  ****** TEST Document ****** 10921
# BroadBeach  not in WE, adding it with random vector
# 62-a-share  not in WE, adding it with random vector
#  ****** TEST Document ****** 10922
# ball-bearing  not in WE, adding it with random vector
#  ****** TEST Document ****** 10923
# 72-a-share  not in WE, adding it with random vector
#  ****** TEST Document ****** 10924
# 101,000  not in WE, adding it with random vector
# 7.3  not in WE, adding it with random vector
#  ****** TEST Document ****** 10925
#  ****** TEST Document ****** 10926
#  ****** TEST Document ****** 10927
#  ****** TEST Document ****** 10928
# co-founded  not in WE, adding it with random vector
# California-based  not in WE, adding it with random vector
#  ****** TEST Document ****** 10929
#  ****** TEST Document ****** 10930
# 133.8  not in WE, adding it with random vector
# 130.1  not in WE, adding it with random vector
#  ****** TEST Document ****** 10931
# 322.7  not in WE, adding it with random vector
#  ****** TEST Document ****** 10932
# 246.6  not in WE, adding it with random vector
# 124.5  not in WE, adding it with random vector
#  ****** TEST Document ****** 10933
# newspaper-delivery  not in WE, adding it with random vector
#  ****** TEST Document ****** 10934
#  ****** TEST Document ****** 10935
# B\/T  not in WE, adding it with random vector
#  ****** TEST Document ****** 10936
#  ****** TEST Document ****** 10937
#  ****** TEST Document ****** 10938
#  ****** TEST Document ****** 10939
#  ****** TEST Document ****** 10940
#  ****** TEST Document ****** 10941
# six-year-old  not in WE, adding it with random vector
# first-ever  not in WE, adding it with random vector
#  ****** TEST Document ****** 10942
#  ****** TEST Document ****** 10943
#  ****** TEST Document ****** 10944
#  ****** TEST Document ****** 10945
#  ****** TEST Document ****** 10946
#  ****** TEST Document ****** 10947
#  ****** TEST Document ****** 10948

# %% [markdown]
# ### Add the (key-value) 'random' word embeddings for missing inputs

# %%
print(len(dictadd))
# Out:
# 4235

# %%
"""
for mot,vecteur in dictadd.items() : 
    wv_pre_trained.add_vector(mot,vecteur)
"""
#Prends beaucoup de temps
# Out:
# '\nfor mot,vecteur in dictadd.items() : \n    wv_pre_trained.add_vector(mot,vecteur)\n'

# %%
emb_size = 300
new_vectors = np.zeros((len(dictadd), emb_size))
for i, (word, vec) in enumerate(dictadd.items()):
    new_vectors[i] = vec
wv_pre_trained.add_vectors(list(dictadd.keys()), new_vectors)

# %% [markdown]
# ### Store the train and test datasets: a word embedding for each token in the sequences

# %%
maxlen = max(max([len(doc) for doc in alldocs]),max([len(doc) for doc in alldocsT]))
wvectors = np.zeros((len(alldocs),maxlen,300))
wvectorsT = np.zeros((len(alldocsT),maxlen,300))
for i,doc in enumerate(alldocs) : 
    for j,(word,pos) in enumerate(doc) :
        wvectors[i,j,:] = wv_pre_trained[word]

# %%
for i,doc in enumerate(alldocsT) : 
    for j,(word,pos) in enumerate(doc) :
        wvectorsT[i,j,:] = wv_pre_trained[word]

# %% [markdown]
# ### Check the size of your train/test datasets

# %%
print(" size de trai",wvectors.shape)
print(" size de test",wvectorsT.shape)
# Out:
#  size de trai (8936, 78, 300)
#  size de test (2012, 78, 300)

# %% [markdown]
# ### Collecting train/test labels

# %%
# Labels train/test

buf2 = [[pos for m,pos in d ] for d in alldocs]
cles = []
[cles.extend(b) for b in buf2]
cles = np.unique(np.array(cles))
cles2ind = dict(zip(cles,range(len(cles))))
nCles = len(cles)
print(nCles," keys in the dictionary")

labels  = np.array([cles2ind[pos] for d in alldocs for (m,pos) in d ])
#np.array([cles2ind[pos] for (m,pos) in d for d in alldocs])
labelsT  = np.array([cles2ind.setdefault(pos,len(cles)) for d in alldocsT for (m,pos) in d ])

print(len(cles2ind)," keys in the dictionary")
# Out:
# 22  keys in the dictionary
# 23  keys in the dictionary

# %% [markdown]
# ### Train a Logistic Regression Model!
# **An compare performances to the baseline and sequence models (HMM/CRF) or practical 2a**

# %%
X = np.array([wvectors[d,m,:] for d,v in enumerate(alldocs) for m,(x,pos) in enumerate(v) ])
X_test = np.array([wvectorsT[d,m,:] for d,v in enumerate(alldocsT) for m,(x,pos) in enumerate(v) ])

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()
clf.fit(X,labels)
print("le score de la bonne classification est :",clf.score(X_test,labelsT))
print(labels[:5])
# Out:
# C:\Users\ykemi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# le score de la bonne classification est : 0.7718724275492328
# [ 5  6  5 15 10]

# %% [markdown]
# # 2) Using word embedding with CRF

# %% [markdown]
# ## We will define the following features functions for CRF

# %%
def features_wv(sentence, index):
    v = wv_pre_trained.get_vector(sentence[index])
    d = {'f'+str(i):v[i] for i in range(300)}
    return d

def features_structural(sentence, index):
    return {
        'word': sentence[index],
        'is_first': index == 0,
        'is_last': index == len(sentence) - 1,
        'is_capitalized': sentence[index][0].upper() == sentence[index][0],
        'is_all_caps': sentence[index].upper() == sentence[index],
        'is_all_lower': sentence[index].lower() == sentence[index],
        'prefix-1': sentence[index][0],
        'prefix-2': sentence[index][:2],
        'prefix-3': sentence[index][:3],
        'suffix-1': sentence[index][-1],
        'suffix-2': sentence[index][-2:],
        'suffix-3': sentence[index][-3:],
        'prev_word': '' if index == 0 else sentence[index - 1],
        'next_word': '' if index == len(sentence) - 1 else sentence[index + 1],
        'has_hyphen': '-' in sentence[index],
        'is_numeric': sentence[index].isdigit(),
     ## We will define the following features functions for CRF## We will define the following features functions for CRF   'capitals_inside': sentence[index][1:].lower() != sentence[index][1:]
    }
def features_wv_plus_structural(sentence, index):
    v = wv_pre_trained.get_vector(sentence[index]) 
    d = {'f'+str(i):v[i] for i in range(300)}

    return {**d, **features_full(sentence, index)}

# %% [markdown]
# ## [Question]: explain what the 3 feature functions encode and what their differences are

# %% [markdown]
# ### Reponses
# ***La premiere fonction prends en argument une phrase et un index d'un certain mot dans la phrase, et retourne le vecteur word2vec sous forme de chaine de caractere, elle capture donc les information sémantique du mots***
#
# ***La deuxieme fonction prends en argument une phrase et un index d'un certain mot dans la phrase, et retourne les information pertinante de ce mots, tel que le prefix, suffix,mot prec, mot suiv extr, elle capture donc les informations syntaxique du mots ***
#
# ***Combine la premiere et la deuxieme pour capturer à la fois les informations syntaxiques et sémantique du mot***

# %% [markdown]
# ### You can now train a CRF with the 3 features and analyse the results

# %%
train = []
for doc in alldocs : 
    train.extend(doc)
print(len(X))
# Out:
# 211727

# %%
train_crf = list()
for i,x in enumerate(X) : 
    train_crf.append((x,labels[i]))

# %%
x_train = []
for doc in alldocs : 
    x_train.append([(word,str(cles2ind[pos])) for word,pos in doc ] )

# %%
print(x_train[:2])
# Out:
# [[('Confidence', '5'), ('in', '6'), ('the', '5'), ('pound', '15'), ('is', '10'), ('widely', '20'), ('expected', '20'), ('to', '20'), ('take', '20'), ('another', '5'), ('sharp', '15'), ('dive', '15'), ('if', '8'), ('trade', '5'), ('figures', '15'), ('for', '6'), ('September', '5'), (',', '21'), ('due', '0'), ('for', '6'), ('release', '5'), ('tomorrow', '5'), (',', '21'), ('fail', '10'), ('to', '20'), ('show', '20'), ('a', '5'), ('substantial', '15'), ('improvement', '15'), ('from', '6'), ('July', '5'), ('and', '15'), ('August', '15'), ("'s", '5'), ('near-record', '15'), ('deficits', '15'), ('.', '21')], [('Chancellor', '21'), ('of', '6'), ('the', '5'), ('Exchequer', '15'), ('Nigel', '5'), ('Lawson', '15'), ("'s", '5'), ('restated', '15'), ('commitment', '15'), ('to', '6'), ('a', '5'), ('firm', '15'), ('monetary', '15'), ('policy', '15'), ('has', '10'), ('helped', '20'), ('to', '20'), ('prevent', '20'), ('a', '5'), ('freefall', '15'), ('in', '6'), ('sterling', '5'), ('over', '6'), ('the', '5'), ('past', '15'), ('week', '15'), ('.', '21')]]

# %%
from nltk.tag.crf import CRFTagger

# Entraîner le tagger CRF sur les données d'entraînement
ct = CRFTagger(feature_func=features_structural)
ct.train(x_train, 'model.crf.tagger')

# Charger le modèle CRF entraîné
## Train the model                  
## Evaluate performances

# %%
x_test = []
for doc in alldocsT: 
    x_test.append([(word,str(cles2ind[pos])) for word,pos in doc ] )

# %%
ct.evaluate(x_test)
# Out:
# 0.9385566836228549
